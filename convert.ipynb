# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np

# %%
#파일 read
src = cv2.imread('./OCR/a.png',cv2.IMREAD_COLOR)
if src is None:
    print('Image load failed!')
#커널 설정
kernel = np.ones((3, 3), np.uint8)

#gray = cv2.cvtColor(src, cv2.COLOR_RGB2GRAY)
#_,binary = cv2.threshold(gray,127, 255,cv2.THRESH_OTSU)
laplacian = cv2.Laplacian(src, cv2.CV_8U, ksize=3)

#erosion = cv2.erode(laplacian, kernel, iterations=1)
Gau = cv2.GaussianBlur(laplacian, (3, 3), 0)

#closing = cv2.morphologyEx(laplacian, cv2.MORPH_CLOSE,kernel)
#dilation = cv2.dilate(laplacian, kernel, iterations=1)
plt.imshow(laplacian, cmap='gray')
cv2.imwrite('convert.png',laplacian)
# Out:
# True
